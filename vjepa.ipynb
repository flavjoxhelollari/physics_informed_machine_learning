# %%
# !git clone https://github.com/facebookresearch/jepa-intuitive-physics.git
# Out:
# Cloning into 'jepa-intuitive-physics'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 69 (delta 2), reused 2 (delta 2), pack-reused 62 (from 1)
# Receiving objects: 100% (69/69), 97.07 MiB | 32.32 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# !cd jepa-intuitive-physics/
# Out:
# /content/jepa-intuitive-physics

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 93.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...

# %%
# !tar -xzvf data_intphys.tar.gz
# Out:
# data_intphys/
# data_intphys/vit-h-rope-vm2m/
# data_intphys/vit-h-rope-vm2m/intphys/
# data_intphys/vit-h-rope-vm2m/intphys/raw_surprises/
# data_intphys/vit-h-rope-vm2m/intphys/raw_surprises/O1_16frames.pth
# data_intphys/vit-h-rope-vm2m/intphys/raw_surprises/O2_16frames.pth
# data_intphys/vit-h-rope-vm2m/intphys/raw_surprises/O3_16frames.pth
# data_intphys/vit-h-rope-vm2m/intphys/performance.csv
# data_intphys/vit-h-rope-vm2m/grasp/
# data_intphys/vit-h-rope-vm2m/grasp/raw_surprises/
# data_intphys/vit-h-rope-vm2m/grasp/raw_surprises/Collision_16frames.pth
# data_intphys/vit-h-rope-vm2m/grasp/raw_surprises/Continuity_16frames.pth
# data_intphys/vit-h-rope-vm2m/grasp/raw_surprises/Gravity_16frames.pth
# data_intphys/vit-h-rope-vm2m/grasp/raw_surprises/GravityContinuity_16frames.pth
# data_intphys/vit-h-rope-vm2m/grasp/raw_surprises/GravityInertia_16frames.pth
# data_intphys/vit-h-rope-vm2m/grasp/raw_surprises/GravityInertia2_16frames.pth
# ...

# %% [markdown]
# # Here check out a way to run evaluation

# %%
# !pip list | grep evals
# !pip install evals
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 46.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 38.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 5.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 MB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 27.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 6.1 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall evals
# Out:
# Found existing installation: evals 3.0.1.post1
# Uninstalling evals-3.0.1.post1:
#   Would remove:
#     /usr/local/bin/oaieval
#     /usr/local/bin/oaievalset
#     /usr/local/lib/python3.11/dist-packages/evals-3.0.1.post1.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/evals/*
# Proceed (Y/n)? y
#   Successfully uninstalled evals-3.0.1.post1

# %%
# !python3 -m evals.main --devices cuda:0 cuda:1 --fname evals/intuitive_physics/configs/default_intphys.yaml
# Out:
# /usr/bin/python3: Error while finding module specification for 'evals.main' (ModuleNotFoundError: No module named 'evals')
